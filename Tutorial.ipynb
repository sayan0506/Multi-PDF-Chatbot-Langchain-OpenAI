# %% [markdown]
# # **Execute Streamlit on Google Colab**

# %% [markdown]
# ## **Install Dependencies**

# %%
# !pip install -r requirements.txt
# !pip install -U langchain-community
# !pip install sentence-transformers
# !pip install faiss-gpu
# !pip install streamlit
# !pip install pyngrok
# !apt-get install -y wget
# !wget https://bin.equinox.io/c/4b7d1c5a11ad/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !pip install faiss-gpu
# Out:
# ...
#   Using cached streamlit-1.37.1-py2.py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl.metadata (38 kB)
# ...
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 17.4 MB/s eta 0:00:00
# ...
# Using cached streamlit-1.37.1-py2.py3-none-any.whl (8.7 MB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 58.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00
# ...
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# ...

# %% [markdown]
# ## **Execute Streamlit APP through ngrok tunnel**

# %%
from pyngrok import ngrok
import subprocess

# Start ngrok tunnel
ngrok.set_auth_token("2krXUtVgch7jIDXcdPKv7c4NtVw_3QmWHZnM45xEf27KeKUVr")  # Replace with your actual ngrok auth token
ngrok_tunnel = ngrok.connect(8501, "http")
print(f"Streamlit app is live at: {ngrok_tunnel.public_url}")


# Run Streamlit app
subprocess.run(["streamlit", "run", "app.py"])
# Out:
# Streamlit app is live at: https://049b-34-124-192-26.ngrok-free.app
